# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
1. Import the data set using pandas

# %%
df=pd.read_csv(r'https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv')
df.head()
# Out:
#   iso_code continent     location      date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  31/12/19          NaN        0.0
# 1      AFG      Asia  Afghanistan  01/01/20          NaN        0.0
# 2      AFG      Asia  Afghanistan  02/01/20          NaN        0.0
# 3      AFG      Asia  Afghanistan  03/01/20          NaN        0.0
# 4      AFG      Asia  Afghanistan  04/01/20          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
2. High Level Data Understanding:
    a. Find no. of rows & columns in the dataset.
    b. Data types of columns.
    c. Info and describe of data in dataframe.

# %%
a. Find no. of rows & columns in the dataset.

# %%
rows = len(df.axes[0])
column = len(df.axes[1])

print("Number of Rows: ", rows)
print("Number of Columns: ", column)
# Out:
# Number of Rows:  57394
# Number of Columns:  49

# %%
b. Data types of columns.

# %%
print("-----Data types of columns-----")
df.dtypes
# Out:
# -----Data types of columns-----
# iso_code                               object
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# ...

# %%
c. Info and describe of data in dataframe.

# %%
print("-----Info of data-----")
print(" ")
df.info()

print(" ")
print(" ")
print("-----Describe of data-----")
print(" ")
df.describe()
# Out:
# -----Info of data-----
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57394 entries, 0 to 57393
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            57071 non-null  object
#  1   continent                           56748 non-null  object
#  2   location                            57394 non-null  object
#  3   date                                57394 non-null  object
#  4   total_cases                         53758 non-null  float64
#  5   new_cases                           56465 non-null  float64
#  6   new_cases_smoothed                  55652 non-null  float64
#  7   total_deaths                        44368 non-null  float64
#  8   new_deaths                          56465 non-null  float64
#  9   new_deaths_smoothed                 55652 non-null  float64
# ...

# %%
3. Low Level Data Understanding:
    a. Find count of unique values in location column.
    b. Find which continent has maximum frequency using values
counts.
    c. Find maximum and mean value in 'total_cases'.
    d. Find 25%, 50% and 75% quartile value in 'total_deaths'.
    e. Find which continent has maximum
    'human_development_index'.
    f. Find which continent has minimum 'gdp_per_capita'.

# %%
a. Find count of unique values in location column.

# %%
print("Number of unique values in location column is :",df['location'].nunique())
print(" ")
print(" ")
print("-----Count of unique values in location column is-----")
df['location'].value_counts()
# Out:
# Number of unique values in location column is : 216
#
#
# -----Count of unique values in location column is-----
# Afghanistan          323
# Iran                 323
# Macedonia            323
# Luxembourg           323
# Lithuania            323
#                     ...
# Hong Kong             72
# Solomon Islands       33
# Wallis and Futuna     32
# Marshall Islands      20
# Vanuatu                7
# Name: location, Length: 216, dtype: int64

# %%
b. Find which continent has maximum frequency using values

# %%
print("Maximum Frequensy is in a continent is : ", df['continent'].value_counts().max())

print(" ")
print("---**---All continents frquency using values---**---\n",df['continent'].value_counts())
# Out:
# Maximum Frequensy is in a continent is :  14828
#
# ---**---All continents frquency using values---**---
#  Europe           14828
# Africa           13637
# Asia             13528
# North America     9116
# South America     3404
# Oceania           2235
# Name: continent, dtype: int64

# %%
c. Find maximum and mean value in 'total_cases'.

# %%
print("maximum value in 'total_cases' : ",df['total_cases'].max())
print(" ")
print("mean value in 'total_cases' : ",df['total_cases'].mean())
# Out:
# maximum value in 'total_cases' :  55154651.0
#
# mean value in 'total_cases' :  167797.3688753302

# %%
d. Find 25%, 50% and 75% quartile value in 'total_deaths'.

# %%
print("25% quartile value in 'total_deaths' : ",df['total_deaths'].quantile(.25))
print("50% quartile value in 'total_deaths' : ",df['total_deaths'].quantile(.50))
print("75% quartile value in 'total_deaths' : ",df['total_deaths'].quantile(.75))
# Out:
# 25% quartile value in 'total_deaths' :  13.0
# 50% quartile value in 'total_deaths' :  84.0
# 75% quartile value in 'total_deaths' :  727.0

# %%
# Another way
print("Please find 25%, 50% and 75% quartile value in 'total_deaths' which is mentioned in below : ")
df['total_deaths'].describe()
# Out:
# Please find 25%, 50% and 75% quartile value in 'total_deaths' which is mentioned in below :
# count    4.436800e+04
# mean     6.858639e+03
# std      5.578081e+04
# min      1.000000e+00
# 25%      1.300000e+01
# 50%      8.400000e+01
# 75%      7.270000e+02
# max      1.328537e+06
# Name: total_deaths, dtype: float64

# %%
e. Find which continent has maximum  'human_development_index'.

# %%
print("Please find below report to know which continent has maximum number of 'human_development_index': ")
print(df.groupby('continent').count()['human_development_index'])



print(" ")
print(" ")
print("Please find below report to know which continent has maximum 'human_development_index'")
df.groupby('continent')['human_development_index'].max()
# Out:
# Please find below report to know which continent has maximum number of 'human_development_index':
# continent
# Africa           13185
# Asia             13205
# Europe           12454
# North America     5986
# Oceania           1241
# South America     3176
# Name: human_development_index, dtype: int64
#
#
# Please find below report to know which continent has maximum 'human_development_index'
# continent
# Africa           0.797
# Asia             0.933
# Europe           0.953
# North America    0.926
# Oceania          0.939
# South America    0.843
# Name: human_development_index, dtype: float64

# %%
f. Find which continent has minimum 'gdp_per_capita'.

# %%
print("Please find below report to know which continent has minimum number of 'gdp_per_capita': ")
print(df.groupby('continent').count()['gdp_per_capita'])



print(" ")
print(" ")
print("Please find below report to know which continent has minimum 'gdp_per_capita' : ")
df.groupby('continent')['gdp_per_capita'].min()
# Out:
# Please find below report to know which continent has minimum number of 'gdp_per_capita':
# continent
# Africa           13185
# Asia             12965
# Europe           12518
# North America     6959
# Oceania           1241
# South America     3176
# Name: gdp_per_capita, dtype: int64
#
#
# Please find below report to know which continent has minimum 'gdp_per_capita' :
# continent
# Africa            661.240
# Asia             1479.147
# Europe           5189.972
# North America    1653.173
# Oceania          2205.923
# South America    6885.829
# Name: gdp_per_capita, dtype: float64

# %%
4. Filter the dataframe with only this columns
 ['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index'] and update the data frame.

# %%
df1=df.filter(items=['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index'])
df.update(df1)
df.head()
# Out:
#   iso_code continent     location      date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  31/12/19          NaN        0.0
# 1      AFG      Asia  Afghanistan  01/01/20          NaN        0.0
# 2      AFG      Asia  Afghanistan  02/01/20          NaN        0.0
# 3      AFG      Asia  Afghanistan  03/01/20          NaN        0.0
# 4      AFG      Asia  Afghanistan  04/01/20          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
5. Data Cleaning

a. Remove all duplicates observations
b. Find missing values in all columns
c. Remove all observations where continent column value is  missing
Tip : using subset parameter in dropna
d. Fill all missing values with 0

# %%
a. Remove all duplicates observations

# %%
df=df.drop_duplicates()
df
# Out:
#       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  31/12/19          NaN        0.0
# 1          AFG      Asia    Afghanistan  01/01/20          NaN        0.0
# 2          AFG      Asia    Afghanistan  02/01/20          NaN        0.0
# 3          AFG      Asia    Afghanistan  03/01/20          NaN        0.0
# 4          AFG      Asia    Afghanistan  04/01/20          NaN        0.0
# ...        ...       ...            ...       ...          ...        ...
# 57389      NaN       NaN  International  13/11/20        696.0        NaN
# 57390      NaN       NaN  International  14/11/20        696.0        NaN
# 57391      NaN       NaN  International  15/11/20        696.0        NaN
# 57392      NaN       NaN  International  16/11/20        696.0        NaN
# 57393      NaN       NaN  International  17/11/20        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
b. Find missing values in all columns

# %%
print(" Please find below data, missing values will be shown as 'False' ")
print(" ")
print(df.isnull())
print(" ")
print(" ")

print(" Please find below data to know number of missing values each coulumns has ")
print(" ")
print(df.isnull().sum())
# Out:
#  Please find below data, missing values will be shown as 'False'
#
#        iso_code  continent  location   date  total_cases  new_cases  \
# 0         False      False     False  False         True      False
# 1         False      False     False  False         True      False
# 2         False      False     False  False         True      False
# 3         False      False     False  False         True      False
# 4         False      False     False  False         True      False
# ...         ...        ...       ...    ...          ...        ...
# 57389      True       True     False  False        False       True
# 57390      True       True     False  False        False       True
# 57391      True       True     False  False        False       True
# 57392      True       True     False  False        False       True
# 57393      True       True     False  False        False       True
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
c. Remove all observations where continent column value is missing
Tip: Using subset Parameter in dropna

# %%
df.dropna(subset = ['continent'],inplace=True)
df['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4          Asia
#           ...
# 56743    Africa
# 56744    Africa
# 56745    Africa
# 56746    Africa
# 56747    Africa
# Name: continent, Length: 56748, dtype: object

# %%
d. Fill all missing values with 0

# %%
df.fillna(0, inplace=True)
df
# Out:
#       iso_code continent     location      date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  31/12/19          0.0        0.0
# 1          AFG      Asia  Afghanistan  01/01/20          0.0        0.0
# 2          AFG      Asia  Afghanistan  02/01/20          0.0        0.0
# 3          AFG      Asia  Afghanistan  03/01/20          0.0        0.0
# 4          AFG      Asia  Afghanistan  04/01/20          0.0        0.0
# ...        ...       ...          ...       ...          ...        ...
# 56743      ZWE    Africa     Zimbabwe  13/11/20       8696.0       29.0
# 56744      ZWE    Africa     Zimbabwe  14/11/20       8765.0       69.0
# 56745      ZWE    Africa     Zimbabwe  15/11/20       8786.0       21.0
# 56746      ZWE    Africa     Zimbabwe  16/11/20       8786.0        0.0
# 56747      ZWE    Africa     Zimbabwe  17/11/20       8897.0      111.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
6. Date time format:
    a. Convert date column in datetime format using pandas.to_datetime
    b. Create new column month after extracting month data from date column

# %%
a. Convert date column in datetime format using pandas.to_datetime

# %%
df['date']=pd.to_datetime(df['date']).dt.strftime('%m/%d/%Y') # here i changed date format to month/date/year
df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  12/31/2019          0.0        0.0
# 1          AFG      Asia  Afghanistan  01/01/2020          0.0        0.0
# 2          AFG      Asia  Afghanistan  02/01/2020          0.0        0.0
# 3          AFG      Asia  Afghanistan  03/01/2020          0.0        0.0
# 4          AFG      Asia  Afghanistan  04/01/2020          0.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 56743      ZWE    Africa     Zimbabwe  11/13/2020       8696.0       29.0
# 56744      ZWE    Africa     Zimbabwe  11/14/2020       8765.0       69.0
# 56745      ZWE    Africa     Zimbabwe  11/15/2020       8786.0       21.0
# 56746      ZWE    Africa     Zimbabwe  11/16/2020       8786.0        0.0
# 56747      ZWE    Africa     Zimbabwe  11/17/2020       8897.0      111.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
b. Create new column month after extracting month data from date column

# %%
df['month'] = pd.DatetimeIndex(df['date']).month
df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  12/31/2019          0.0        0.0
# 1          AFG      Asia  Afghanistan  01/01/2020          0.0        0.0
# 2          AFG      Asia  Afghanistan  02/01/2020          0.0        0.0
# 3          AFG      Asia  Afghanistan  03/01/2020          0.0        0.0
# 4          AFG      Asia  Afghanistan  04/01/2020          0.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 56743      ZWE    Africa     Zimbabwe  11/13/2020       8696.0       29.0
# 56744      ZWE    Africa     Zimbabwe  11/14/2020       8765.0       69.0
# 56745      ZWE    Africa     Zimbabwe  11/15/2020       8786.0       21.0
# 56746      ZWE    Africa     Zimbabwe  11/16/2020       8786.0        0.0
# 56747      ZWE    Africa     Zimbabwe  11/17/2020       8897.0      111.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
7. Data Agregation:
    a. Find max value in all columns using groupby function on 'continent'
    Tip: use reset _index() after applying groupby
    b. Store the result in a new dataframe named 'df_groupby'. (Use df_groupby dataframe for all further analysis)

# %%
a. Find max value in all columns using groupby function on 'continent'
    Tip: use reset _index() after applying groupby

# %%
df.groupby('continent').max().reset_index()
# Out:
#        continent iso_code                      location        date  \
# 0         Africa      ZWE                      Zimbabwe  12/31/2019
# 1           Asia      YEM                         Yemen  12/31/2019
# 2         Europe      VAT                       Vatican  12/31/2019
# 3  North America      VIR  United States Virgin Islands  12/31/2019
# 4        Oceania      WLF             Wallis and Futuna  12/31/2019
# 5  South America      VEN                     Venezuela  12/31/2019
#
#    total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0     752269.0    13944.0           12583.714       20314.0       572.0
# 1    8874290.0    97894.0           93198.571      130519.0      2003.0
# 2    1991233.0    86852.0           54868.571       52147.0      2004.0
# 3   11205486.0   184813.0          156419.143      247220.0      4928.0
# 4      27750.0     1384.0             551.714         907.0        59.0
# ...

# %%
b. Store the result in a new dataframe named 'df_groupby'. (Use df_groupby dataframe for all further analysis)

# %%
df_groupby = df.groupby('continent').max().reset_index()
df_groupby.head()
# Out:
#        continent iso_code                      location        date  \
# 0         Africa      ZWE                      Zimbabwe  12/31/2019
# 1           Asia      YEM                         Yemen  12/31/2019
# 2         Europe      VAT                       Vatican  12/31/2019
# 3  North America      VIR  United States Virgin Islands  12/31/2019
# 4        Oceania      WLF             Wallis and Futuna  12/31/2019
#
#    total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0     752269.0    13944.0           12583.714       20314.0       572.0
# 1    8874290.0    97894.0           93198.571      130519.0      2003.0
# 2    1991233.0    86852.0           54868.571       52147.0      2004.0
# 3   11205486.0   184813.0          156419.143      247220.0      4928.0
# 4      27750.0     1384.0             551.714         907.0        59.0
#
#    new_deaths_smoothed  ...  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
8. Feature Engineering:
    a. Create a new feature 'total_deaths_to_total_cases' by ratio of 'total_deaths' column to 'total_cases'

# %%
df['total_deaths_to_total_cases'] = df['total_deaths']/df['total_cases']
df['total_deaths_to_total_cases']
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 56743    0.029324
# 56744    0.029321
# 56745    0.029251
# 56746    0.029251
# 56747    0.028886
# Name: total_deaths_to_total_cases, Length: 56748, dtype: float64

# %%
9. Data Visualization:
    a. Perform Univariate analysis on 'gdp_per_capita' column by plotting histogram using seaborn dist plot.
    b. Plot a scatter plot of 'total_cases' & 'gdp_per_capita'
    c. Plot Pairplot on df_groupby dataset.
    d. Plot a bar plot of 'continent' column with 'total_cases'.

# %%
a. Perform Univariate analysis on 'gdp_per_capita' column by plotting histogram using seaborn dist plot.

# %%
sns_dist = sns.distplot(df['gdp_per_capita']) 

sns_dist.figure.savefig("sns_distplot.pdf")  # saving dist plot in my drive

sns_dist
# Out:
# D:\Data Science\edyodha packages\Anaconda Packages\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='gdp_per_capita', ylabel='Density'>

# %%
sns_dist_kde = sns.distplot(df['gdp_per_capita'],hist=False,color='darkorange') 

sns_dist_kde.figure.savefig("sns_distplot_kde.pdf")  # saving dist plot in my drive

sns_dist_kde
# Out:
# D:\Data Science\edyodha packages\Anaconda Packages\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='gdp_per_capita', ylabel='Density'>

# %%
sns_dist_hist = sns.distplot(df['gdp_per_capita'],kde=False,color='darkorange') 

sns_dist_hist.figure.savefig("sns_distplot_hist.pdf")  # saving dist plot in my drive

sns_dist_hist
# Out:
# D:\Data Science\edyodha packages\Anaconda Packages\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='gdp_per_capita'>

# %%
b. Plot a scatter plot of 'total_cases' & 'gdp_per_capita'

# %%
plt_scatter = plt.scatter(y=df['total_cases'],x=df['gdp_per_capita'],c ="orange")
plt.xlabel('gdp_per_capita')  
plt.ylabel('total_cases')  

plt_scatter.figure.savefig("plt_scatter.pdf")  # saving scatter plot in my drive

plt.show(plt_scatter)

# %%
c. Plot Pairplot on df_groupby dataset.

# %%
pair_plot = sns.pairplot(df_groupby)   # it has a uge data so that i couldn't get exact pair plot

pair_plot.figure.savefig("pair_plot.pdf")  # saving pair plot in my drive

pair_plot

# %%
d. Plot a bar plot of 'continent' column with 'total_cases'.
Tip: using kind='bar' in seaborn catplot

# %%
cat_plot = sns.catplot(x='continent', y='total_cases', data=df, kind='bar',height=6,aspect=1.5)

cat_plot.figure.savefig("cat_plot.pdf")  # saving car plot in my drive

cat_plot

# %%
10. Save all df_groupby dataframe in your local drive using pandas.to_csv function.

# %%
df_groupby.to_csv(r"D:\Data Science\DATA WRANGLING & VISUALIZATION\Assignments\Project\df_groupby.csv", index=False) # saving 'df_groupby' data

df.to_csv(r"D:\Data Science\DATA WRANGLING & VISUALIZATION\Assignments\Project\df.csv", index=False)  #saving 'df' data
